# %% [markdown]
# #### Roteiro Apresentação
# 1. Capa
# 2. Contexto
# 3. Problema
# 4. Objetivos
#     - Objetivo geral: criar um observatório de dados descritivo das despesas da proadmi
#     - Objetivos específicos:
#         - Analisar a distribuição geral dos gastos
#         - Analisar as características dos empenhos
#         - Analisar as características dos credores
# 5. Dados
#     - Base coletada do portal da transparência do governo de pernambuco, com foco nas unidades gestoras: POLI, PROADMI E OSWALDO CRUZ, no período de 2023 a abril de 2026
#     - Base coletada: 7806
#     - Base gerada: 2341
#     - Base utilizada: 10147
# 6. Método (oculto)
# 7. Demonstração do Observatório
# 8. Quais insights podem ser extraidos do dashboard
#     - Aba geral: visão macro da distribuição das despesas executadas pela proadmi
#         - Valores totais e taxa de execução
#         - Série Temporal dos gastos
#         - Distribuições por fonte de recurso, Ação e Função
#     - Aba empenhos: distribuição das despesas de acordo com os empenhos
#         - Valor, quantidade total e tickt médio por empenho
#         - Distribuição dos empenhos por faixas de valores, total empenhado anual, modalidade, empenhado/liquidado por tipo de despesa
#         - Previsão de valores empenhados nos próximos três meses
#     - Aba credores: distribuição das despesas empenhadas para cada credor
#         - Total de credores, ticket médio por credor
#         - Ranking de credores por valor empenhado, ranking de credores por cluster identificado
#         - Distribuiçao dos credores por % de valor empenhado
#         - Participação do credor no total empenhado por ano
#     - Aba ficha individual: resumo/histórico individual do credor com a pro-reitoria
#         - Valores e ticket médio por credor
#         - Total de empenhos, taxa de execução e saldo a ser pago
#         - Linha do tempo de repasses
#         - Resumo do histórico do relacionamento com o credor (tabela)
# 9. Limitações
#     - Base de dados
#     - Recurso computacional
# 10. Propostas de Melhorias
#     - Enriquecimento da base de dados
#     - Refinamento dos modelos de clusterização e previsão
# 11. Obrigado

# %%
import pandas as pd
import plotly.express as px

dados_entrada = "../data/data_apresentacao.csv"

df = pd.read_csv(f'{dados_entrada}', sep=',', encoding='utf-8')

# %%
len(df['origem_dado'])
# Out:
# 10147

# %%
df['origem_dado'].value_counts()
# Out:
# origem_dado
# real         7806
# sintetico    2341
# Name: count, dtype: int64
